# %% [markdown]
# # Importing basic libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import warnings
warnings.filterwarnings('ignore')
import plotly.express as px

# Machine Learning (Regression, Classification, Clustering)
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.svm import SVC
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import (
    mean_squared_error, r2_score,
    accuracy_score, confusion_matrix, classification_report,
    silhouette_score
)
import xgboost as xgb
import lightgbm as lgb

# Explainable AI (XAI)
import shap
# !pip install lime
import lime
import lime.lime_tabular
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283834 sha256=7d302faae164ea7249f016f768456037ebeb57bc7c528734e108358173952784
#   Stored in directory: /root/.cache/pip/wheels/85/fa/a3/9c2d44c9f3cd77cf4e533b58900b2bf4487f2a17e8ec212a3d
# Successfully built lime
# ...

# %% [markdown]
# # EU PARK EDA

# %%
park_food_sales = pd.read_csv("/content/drive/MyDrive/ML Presentation WS/EU_park_food_sales.csv")
park_customers = pd.read_csv("/content/drive/MyDrive/ML Presentation WS/EU-Park-Customers.csv")

# %%
print(f"Shape of Food sales dataset:",park_food_sales.shape)
print(f"Shape of costumers dataset:",park_customers.shape)
# Out:
# Shape of Food sales dataset: (1000, 30)
# Shape of costumers dataset: (10000, 7)

# %%
print(park_food_sales.columns)
print("-------------------------------------------------------------")
print(park_customers.columns)
# Out:
# Index(['Hamburger', 'Cheeseburger', 'Veggie Burger', 'Hot Dog',
#        'Chicken Sandwich', 'Fries', 'Onion Rings', 'Salad', 'Pizza Slice',
#        'Nachos', 'Ice Cream', 'Cupcake', 'Cookie', 'Candy', 'Popcorn',
#        'Soft Drink', 'Water', 'Juice', 'Coffee', 'Tea', 'Milkshake',
#        'Smoothie', 'Beer', 'Wine', 'Cocktail', 'Pretzel', 'Churros',
#        'Cotton Candy', 'Corn Dog', 'Tacos'],
#       dtype='object')
# -------------------------------------------------------------
# Index(['Age', 'Telephone_Number', 'Family_Members_with_Passes',
#        'Previously_Owned_Passes', 'Club_Member', 'Distance_from_Park_km',
#        'Pass_Type'],
#       dtype='object')

# %% [markdown]
# # SmartBuild - manufacturer company dataset EDA

# %%
SB_setting = pd.read_csv("/content/drive/MyDrive/ML Presentation WS/Machine_Settings_Log_01.csv")
SB_prod = pd.read_csv("/content/drive/MyDrive/ML Presentation WS/Production_Log_01.csv")

# %%
print(f"Shape of Production dataset:",SB_prod.shape)
print(f"Shape of Setting dataset:",SB_setting.shape)
# Out:
# Shape of Production dataset: (10000, 20)
# Shape of Setting dataset: (10000, 3)

# %%
print(SB_prod.columns)
print("---------------------------------------")
print(SB_setting.columns)
# Out:
# Index(['id', 'width', 'height', 'ionizationclass', 'FluxCompensation',
#        'pressure', 'karma', 'modulation', 'configuration_log_ID',
#        'weight_in_kg', 'weight_in_g', 'error', 'error_type', 'Quality',
#        'reflectionScore', 'distortion', 'nicesness', 'smartness',
#        'multideminsionality', 'roughness'],
#       dtype='object')
# ---------------------------------------
# Index(['configuration_log_ID', 'gear', 'rotation_speed'], dtype='object')
